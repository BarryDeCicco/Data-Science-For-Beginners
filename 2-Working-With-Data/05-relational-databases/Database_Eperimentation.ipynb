# %% [markdown]
# <a href="https://colab.research.google.com/github/BarryDeCicco/Data-Science-For-Beginners/blob/main/2-Working-With-Data/05-relational-databases/Database_Eperimentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Opening SQL db 'airports.db'.

# %%
import sqlite3
import pandas as pd

# Connect to your SQLite database (replace 'your_database.db' with your actual database file name)
conn = sqlite3.connect('airports.db')

# Query the sqlite_master table to get table names
query = "SELECT name FROM sqlite_master WHERE type='table';"
tables_df = pd.read_sql_query(query, conn)

# Print the list of table names
print("Tables in the database:")
print(tables_df['name'].tolist())

# Close the connection
conn.close()
# Out:
# Tables in the database:
# ['Cities', 'sqlite_sequence', 'Airports']

# %%
# Connect to your SQLite database (replace 'your_database.db' with your actual database file name)
conn = sqlite3.connect('airports.db')

# Query the sqlite_master table to get table names
query = "SELECT * FROM Cities;"
Cities_df = pd.read_sql_query(query, conn)

# Print the dataframe
print("Contents of the Cities table:")
display(Cities_df)

# Close the connection
conn.close()
# Out:
# Contents of the Cities table:
#       id         city         country
# 0      2      Belfast  United Kingdom
# 1      3  Enniskillen  United Kingdom
# 2      5  Londonderry  United Kingdom
# 3      6   Birmingham  United Kingdom
# 4      7     Coventry  United Kingdom
# ..   ...          ...             ...
# 165  178     Goodwood  United Kingdom
# 166  179    Spadeadam  United Kingdom
# 167  180      Kinloss  United Kingdom
# 168  181         Mona  United Kingdom
# 169  182     Longwood  United Kingdom
#
# [170 rows x 3 columns]

# %%
# Connect to your SQLite database (replace 'your_database.db' with your actual database file name)
conn = sqlite3.connect('airports.db')

# Query the sqlite_master table to get table names
query = "SELECT * FROM Airports;"
Airports_df = pd.read_sql_query(query, conn)

# Print the dataframe
print("Contents of the Airports table:")
display(Airports_df)

# Close the connection
conn.close()
# Out:
# Contents of the Airports table:
#       id                              name  code  city_id
# 0    183     Belfast International Airport  EGAA      2.0
# 1    184                 St Angelo Airport  EGAB      3.0
# 2    185  George Best Belfast City Airport  EGAC      2.0
# 3    186             City of Derry Airport  EGAE      5.0
# 4    187  Birmingham International Airport  EGBB      6.0
# ..   ...                               ...   ...      ...
# 176  359       Chichester/Goodwood Airport  EGHR    178.0
# 177  360                     RAF Spadeadam  EGOM    179.0
# 178  361                       RAF Kinloss  EGQK    180.0
# 179  362                          RAF Mona  EGOQ    181.0
# 180  363                St. Helena Airport  FHSH    182.0
#
# [181 rows x 4 columns]

# %%
# Connect to your SQLite database (replace 'your_database.db' with your actual database file name)
conn = sqlite3.connect('airports.db')

# Query the sqlite_master table to get table names
query = "SELECT * FROM sqlite_sequence;"
sqlite_sequence_df = pd.read_sql_query(query, conn)

# Print the dataframe
print("Contents of the sqlite_sequence table:")
display(sqlite_sequence_df)

# Close the connection
conn.close()
# Out:
# Contents of the sqlite_sequence table:
#        name  seq
# 0    Cities  544
# 1  Airports  363
